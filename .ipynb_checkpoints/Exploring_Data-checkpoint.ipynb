# %% [markdown]
# <div style="text-align: center; background-color: #5A96E3; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Exploring Data</div>

# %% [markdown]
# <h2>Import</h2>

# %%
import numpy as np
import pandas as pd
import datetime

# %% [markdown]
# <h2>Exploring your data</h2>

# %% [markdown]
# <h3>Read raw data from file</h3>

# %%
raw_df = pd.DataFrame()
raw_df=pd.read_csv('data_footballer.csv')

# %%
# TEST
raw_df.head()
# Out:
#                 Name  Height Weight Preferred Foot     Birth Date  Age  \
# 0    Erling Haaland   195 cm  94 kg           Left  July 21, 2000   23
# 1     Kylian Mbappé   182 cm  75 kg          Right  Dec. 20, 1998   24
# 2   Kevin De Bruyne   181 cm  75 kg          Right  June 28, 1991   32
# 3        Harry Kane   188 cm  85 kg          Right  July 28, 1993   30
# 4  Thibaut Courtois   199 cm  96 kg           Left   May 11, 1992   31
#
#     Nation Preferred Positions  OVR  POT  ... Long Shots Curve  FK Acc.  \
# 0   Norway                  ST   91   94  ...         86    77       62
# 1   France              ST, LW   91   94  ...         83    80       69
# 2  Belgium             CM, CAM   91   91  ...         92    92       83
# 3  England                  ST   90   90  ...         87    82       65
# 4  Belgium                  GK   90   90  ...         17    19       20
#
#    Penalties Volleys  GK Positioning  GK Diving  GK Handling  GK Kicking  \
# 0         84      90              11          7           14          13
# 1         84      85              11         13            5           7
# 2         83      83              10         15           13           5
# 3         92      89              14          8           10          11
# 4         27      12              90         85           89          76
#
#    GK Reflexes
# 0            7
# 1            6
# 2           13
# 3           11
# 4           93
#
# [5 rows x 46 columns]

# %% [markdown]
# <h3>How many rows and how many columns does the raw data have?</h3>

# %%
rows=len(raw_df.axes[0])
cols=len(raw_df.axes[1])
shape=(rows,cols)
print(f"Current shape: {shape}")
# Out:
# Current shape: (10020, 46)

# %% [markdown]
# <h3>What data type does each column currently have? Are there any columns whose data types are not suitable for further processing?</h3>

# %% [markdown]
# <h4>Convert all columns into their correct datatype before doing anything else</h4>

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10020 entries, 0 to 10019
# Data columns (total 46 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 10020 non-null  object
#  1   Height               10020 non-null  object
#  2   Weight               10020 non-null  object
#  3   Preferred Foot       10020 non-null  object
#  4   Birth Date           10020 non-null  object
#  5   Age                  10020 non-null  int64
#  6   Nation               10020 non-null  object
#  7   Preferred Positions  10020 non-null  object
#  8   OVR                  10020 non-null  int64
#  9   POT                  10020 non-null  int64
#  10  Value                10020 non-null  object
#  11  Wage                 10020 non-null  object
#  12  Ball Control         10020 non-null  int64
#  13  Dribbling            10020 non-null  int64
#  14  Marking              10020 non-null  object
#  15  Slide Tackle         10020 non-null  int64
#  16  Stand Tackle         10020 non-null  int64
#  17  Aggression           10020 non-null  int64
#  18  Reactions            10020 non-null  int64
#  19  Att. Position        10020 non-null  int64
#  20  Interceptions        10020 non-null  int64
#  21  Vision               10020 non-null  int64
#  22  Composure            10020 non-null  int64
#  23  Crossing             10020 non-null  int64
#  24  Short Pass           10020 non-null  int64
#  25  Long Pass            10020 non-null  int64
#  26  Acceleration         10020 non-null  int64
#  27  Stamina              10020 non-null  int64
#  28  Strength             10020 non-null  int64
#  29  Balance              10020 non-null  int64
#  30  Sprint Speed         10020 non-null  int64
#  31  Agility              10020 non-null  int64
#  32  Jumping              10020 non-null  int64
#  33  Heading              10020 non-null  int64
#  34  Shot Power           10020 non-null  int64
#  35  Finishing            10020 non-null  int64
#  36  Long Shots           10020 non-null  int64
#  37  Curve                10020 non-null  int64
#  38  FK Acc.              10020 non-null  int64
#  39  Penalties            10020 non-null  int64
#  40  Volleys              10020 non-null  int64
#  41  GK Positioning       10020 non-null  int64
#  42  GK Diving            10020 non-null  int64
#  43  GK Handling          10020 non-null  int64
#  44  GK Kicking           10020 non-null  int64
#  45  GK Reflexes          10020 non-null  int64
# dtypes: int64(36), object(10)
# memory usage: 3.5+ MB

# %% [markdown]
# Column `Birth Date` should be converted to datetime.

# %%
cols_change=['Value','Wage', 'Marking']
raw_df['Value'] = raw_df['Value'].str.replace('.','')
raw_df[cols_change] = raw_df[cols_change].apply(pd.to_numeric, errors='coerce')
raw_df['Birth Date'] = raw_df['Birth Date'].str.replace('.','').str.replace('Sept', 'Sep')
converted_dates = []
for i in range(len(raw_df['Birth Date'])):
    try:
        converted_dates.append(pd.to_datetime(raw_df['Birth Date'].iloc[i], format='%b %d, %Y'))
    except ValueError:
        converted_dates.append(pd.to_datetime(raw_df['Birth Date'].iloc[i], format='%B %d, %Y'))

raw_df['Birth Date'] = converted_dates
raw_df['Height'] = raw_df['Height'].str.rstrip(' cm').astype(int)
raw_df['Weight'] = raw_df['Weight'].str.rstrip(' kg').astype(int)
# Out:
# /tmp/ipykernel_3245/2473061672.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   raw_df['Value'] = raw_df['Value'].str.replace('.','')
# /tmp/ipykernel_3245/2473061672.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   raw_df['Birth Date'] = raw_df['Birth Date'].str.replace('.','').str.replace('Sept', 'Sep')

# %%
# TEST
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10020 entries, 0 to 10019
# Data columns (total 46 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 10020 non-null  object
#  1   Height               10020 non-null  int64
#  2   Weight               10020 non-null  int64
#  3   Preferred Foot       10020 non-null  object
#  4   Birth Date           10020 non-null  datetime64[ns]
#  5   Age                  10020 non-null  int64
#  6   Nation               10020 non-null  object
#  7   Preferred Positions  10020 non-null  object
#  8   OVR                  10020 non-null  int64
#  9   POT                  10020 non-null  int64
#  10  Value                9961 non-null   float64
#  11  Wage                 9961 non-null   float64
#  12  Ball Control         10020 non-null  int64
#  13  Dribbling            10020 non-null  int64
#  14  Marking              0 non-null      float64
#  15  Slide Tackle         10020 non-null  int64
#  16  Stand Tackle         10020 non-null  int64
#  17  Aggression           10020 non-null  int64
#  18  Reactions            10020 non-null  int64
#  19  Att. Position        10020 non-null  int64
#  20  Interceptions        10020 non-null  int64
#  21  Vision               10020 non-null  int64
#  22  Composure            10020 non-null  int64
#  23  Crossing             10020 non-null  int64
#  24  Short Pass           10020 non-null  int64
#  25  Long Pass            10020 non-null  int64
#  26  Acceleration         10020 non-null  int64
#  27  Stamina              10020 non-null  int64
#  28  Strength             10020 non-null  int64
#  29  Balance              10020 non-null  int64
#  30  Sprint Speed         10020 non-null  int64
#  31  Agility              10020 non-null  int64
#  32  Jumping              10020 non-null  int64
#  33  Heading              10020 non-null  int64
#  34  Shot Power           10020 non-null  int64
#  35  Finishing            10020 non-null  int64
#  36  Long Shots           10020 non-null  int64
#  37  Curve                10020 non-null  int64
#  38  FK Acc.              10020 non-null  int64
#  39  Penalties            10020 non-null  int64
#  40  Volleys              10020 non-null  int64
#  41  GK Positioning       10020 non-null  int64
#  42  GK Diving            10020 non-null  int64
#  43  GK Handling          10020 non-null  int64
#  44  GK Kicking           10020 non-null  int64
#  45  GK Reflexes          10020 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(38), object(4)
# memory usage: 3.5+ MB

# %% [markdown]
# <h3>Check missing value and solve missing value in data</h3>

# %%
missing_ratio=(raw_df.isnull().sum()/len(raw_df)*100).round(2)
missing_ratio
# Out:
# Name                     0.00
# Height                   0.00
# Weight                   0.00
# Preferred Foot           0.00
# Birth Date               0.00
# Age                      0.00
# Nation                   0.00
# Preferred Positions      0.00
# OVR                      0.00
# POT                      0.00
# Value                    0.59
# Wage                     0.59
# Ball Control             0.00
# Dribbling                0.00
# Marking                100.00
# Slide Tackle             0.00
# Stand Tackle             0.00
# Aggression               0.00
# Reactions                0.00
# Att. Position            0.00
# Interceptions            0.00
# Vision                   0.00
# Composure                0.00
# Crossing                 0.00
# Short Pass               0.00
# Long Pass                0.00
# Acceleration             0.00
# Stamina                  0.00
# Strength                 0.00
# Balance                  0.00
# Sprint Speed             0.00
# Agility                  0.00
# Jumping                  0.00
# Heading                  0.00
# Shot Power               0.00
# Finishing                0.00
# Long Shots               0.00
# Curve                    0.00
# FK Acc.                  0.00
# Penalties                0.00
# Volleys                  0.00
# GK Positioning           0.00
# GK Diving                0.00
# GK Handling              0.00
# GK Kicking               0.00
# GK Reflexes              0.00
# dtype: float64

# %% [markdown]
# If the percentage of missing values is greater than 75%, the column is dropped from the dataframe.

# %%
for i in missing_ratio.keys():
    if missing_ratio[i]>75.0:
        raw_df=raw_df.drop(columns=[i])

# %%
# TEST
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10020 entries, 0 to 10019
# Data columns (total 45 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 10020 non-null  object
#  1   Height               10020 non-null  int64
#  2   Weight               10020 non-null  int64
#  3   Preferred Foot       10020 non-null  object
#  4   Birth Date           10020 non-null  datetime64[ns]
#  5   Age                  10020 non-null  int64
#  6   Nation               10020 non-null  object
#  7   Preferred Positions  10020 non-null  object
#  8   OVR                  10020 non-null  int64
#  9   POT                  10020 non-null  int64
#  10  Value                9961 non-null   float64
#  11  Wage                 9961 non-null   float64
#  12  Ball Control         10020 non-null  int64
#  13  Dribbling            10020 non-null  int64
#  14  Slide Tackle         10020 non-null  int64
#  15  Stand Tackle         10020 non-null  int64
#  16  Aggression           10020 non-null  int64
#  17  Reactions            10020 non-null  int64
#  18  Att. Position        10020 non-null  int64
#  19  Interceptions        10020 non-null  int64
#  20  Vision               10020 non-null  int64
#  21  Composure            10020 non-null  int64
#  22  Crossing             10020 non-null  int64
#  23  Short Pass           10020 non-null  int64
#  24  Long Pass            10020 non-null  int64
#  25  Acceleration         10020 non-null  int64
#  26  Stamina              10020 non-null  int64
#  27  Strength             10020 non-null  int64
#  28  Balance              10020 non-null  int64
#  29  Sprint Speed         10020 non-null  int64
#  30  Agility              10020 non-null  int64
#  31  Jumping              10020 non-null  int64
#  32  Heading              10020 non-null  int64
#  33  Shot Power           10020 non-null  int64
#  34  Finishing            10020 non-null  int64
#  35  Long Shots           10020 non-null  int64
#  36  Curve                10020 non-null  int64
#  37  FK Acc.              10020 non-null  int64
#  38  Penalties            10020 non-null  int64
#  39  Volleys              10020 non-null  int64
#  40  GK Positioning       10020 non-null  int64
#  41  GK Diving            10020 non-null  int64
#  42  GK Handling          10020 non-null  int64
#  43  GK Kicking           10020 non-null  int64
#  44  GK Reflexes          10020 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(38), object(4)
# memory usage: 3.4+ MB

# %% [markdown]
# After remove features which have large missing values, our dataframe still have missing values. So that, we need to fill these missing values so that they can be used in analysis.

# %%
# Với 2 cột Value và Wage điền giá trị NaN bằng trung bình của hai giá trị bên cạnh
raw_df['Value'] = raw_df['Value'].fillna((raw_df['Value'].shift() + raw_df['Value'].shift(-1)) / 2)
raw_df['Wage'] = raw_df['Wage'].fillna((raw_df['Wage'].shift() + raw_df['Wage'].shift(-1)) / 2)
# Hiển thị DataFrame sau khi điền giá trị NaN
display(raw_df)
# Out:
#                     Name  Height  Weight Preferred Foot Birth Date  Age  \
# 0        Erling Haaland      195      94           Left 2000-07-21   23
# 1         Kylian Mbappé      182      75          Right 1998-12-20   24
# 2       Kevin De Bruyne      181      75          Right 1991-06-28   32
# 3            Harry Kane      188      85          Right 1993-07-28   30
# 4      Thibaut Courtois      199      96           Left 1992-05-11   31
# ...                  ...     ...     ...            ...        ...  ...
# 10015     Tim Schreiber      191      87          Right 2002-04-24   21
# 10016     Calvin Ramsay      177      68          Right 2003-07-31   20
# 10017     Tomás Salazar      170      60          Right 2000-06-06   23
# 10018     Arda Kızıldağ      187      77          Right 1998-10-15   25
# 10019     Cristian Cauz      188      78           Left 1996-08-15   27
#
#          Nation Preferred Positions  OVR  POT  ...  Long Shots  Curve  \
# 0        Norway                  ST   91   94  ...          86     77
# 1        France              ST, LW   91   94  ...          83     80
# 2       Belgium             CM, CAM   91   91  ...          92     92
# 3       England                  ST   90   90  ...          87     82
# 4       Belgium                  GK   90   90  ...          17     19
# ...         ...                 ...  ...  ...  ...         ...    ...
# 10015   Germany                  GK   65   75  ...           6     11
# 10016  Scotland             RWB, RB   65   81  ...          43     61
# 10017  Colombia                  CM   65   74  ...          64     49
# 10018    Turkey                  CB   65   72  ...          31     28
# 10019     Italy              LB, CB   65   66  ...          46     60
#
#        FK Acc.  Penalties  Volleys  GK Positioning  GK Diving  GK Handling  \
# 0           62         84       90              11          7           14
# 1           69         84       85              11         13            5
# 2           83         83       83              10         15           13
# 3           65         92       89              14          8           10
# 4           20         27       12              90         85           89
# ...        ...        ...      ...             ...        ...          ...
# 10015       11         18        9              59         69           61
# 10016       54         42       27               9         13            8
# 10017       60         55       38               5          6           11
# 10018       33         53       29              13         10           13
# 10019       48         54       39               7         11           10
#
#        GK Kicking  GK Reflexes
# 0              13            7
# 1               7            6
# 2               5           13
# 3              11           11
# 4              76           93
# ...           ...          ...
# 10015          63           70
# 10016           9            8
# 10017           8           10
# 10018          14            9
# 10019          14            7
#
# [10020 rows x 45 columns]

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10020 entries, 0 to 10019
# Data columns (total 45 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 10020 non-null  object
#  1   Height               10020 non-null  int64
#  2   Weight               10020 non-null  int64
#  3   Preferred Foot       10020 non-null  object
#  4   Birth Date           10020 non-null  datetime64[ns]
#  5   Age                  10020 non-null  int64
#  6   Nation               10020 non-null  object
#  7   Preferred Positions  10020 non-null  object
#  8   OVR                  10020 non-null  int64
#  9   POT                  10020 non-null  int64
#  10  Value                10013 non-null  float64
#  11  Wage                 10013 non-null  float64
#  12  Ball Control         10020 non-null  int64
#  13  Dribbling            10020 non-null  int64
#  14  Slide Tackle         10020 non-null  int64
#  15  Stand Tackle         10020 non-null  int64
#  16  Aggression           10020 non-null  int64
#  17  Reactions            10020 non-null  int64
#  18  Att. Position        10020 non-null  int64
#  19  Interceptions        10020 non-null  int64
#  20  Vision               10020 non-null  int64
#  21  Composure            10020 non-null  int64
#  22  Crossing             10020 non-null  int64
#  23  Short Pass           10020 non-null  int64
#  24  Long Pass            10020 non-null  int64
#  25  Acceleration         10020 non-null  int64
#  26  Stamina              10020 non-null  int64
#  27  Strength             10020 non-null  int64
#  28  Balance              10020 non-null  int64
#  29  Sprint Speed         10020 non-null  int64
#  30  Agility              10020 non-null  int64
#  31  Jumping              10020 non-null  int64
#  32  Heading              10020 non-null  int64
#  33  Shot Power           10020 non-null  int64
#  34  Finishing            10020 non-null  int64
#  35  Long Shots           10020 non-null  int64
#  36  Curve                10020 non-null  int64
#  37  FK Acc.              10020 non-null  int64
#  38  Penalties            10020 non-null  int64
#  39  Volleys              10020 non-null  int64
#  40  GK Positioning       10020 non-null  int64
#  41  GK Diving            10020 non-null  int64
#  42  GK Handling          10020 non-null  int64
#  43  GK Kicking           10020 non-null  int64
#  44  GK Reflexes          10020 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(38), object(4)
# memory usage: 3.4+ MB

# %% [markdown]
# <h3>Group feature</h3>

# %% [markdown]
# `raw_df` have so many columnns, that make them distracted to analyze.
# To further streamline the dataset and improve analytical focus, consider merging related columns into cohesive groups, such as **'Ball Skills,' 'Defence,' 'Mental,' 'Passing,' 'Physical,' 'Shooting,' and 'Goalkeeper.'**
# This grouping approach enhances the organization of the data, making it more accessible and facilitating a more insightful analysis of player performance.

# %%
raw_df['Ball Skills']=(raw_df['Ball Control']+raw_df['Dribbling'])/2
raw_df['Defence']=(raw_df['Slide Tackle']+raw_df['Stand Tackle'])/2
raw_df['Mental'] = raw_df.loc[:,'Aggression':'Composure'].mean(axis=1)
raw_df['Passing'] = raw_df.loc[:,'Crossing':'Long Pass'].mean(axis=1)
raw_df['Physical'] = raw_df.loc[:,'Acceleration':'Jumping'].mean(axis=1)
raw_df['Shooting'] = raw_df.loc[:,'Heading':'Volleys'].mean(axis=1)
raw_df['Goalkeeper'] = raw_df.loc[:,'GK Positioning':'GK Reflexes'].mean(axis=1)
raw_df.drop(columns=raw_df.columns[11:43], inplace=True)

# %%
raw_df = round(raw_df, 1)
raw_df
# Out:
#                     Name  Height  Weight Preferred Foot Birth Date  Age  \
# 0        Erling Haaland      195      94           Left 2000-07-21   23
# 1         Kylian Mbappé      182      75          Right 1998-12-20   24
# 2       Kevin De Bruyne      181      75          Right 1991-06-28   32
# 3            Harry Kane      188      85          Right 1993-07-28   30
# 4      Thibaut Courtois      199      96           Left 1992-05-11   31
# ...                  ...     ...     ...            ...        ...  ...
# 10015     Tim Schreiber      191      87          Right 2002-04-24   21
# 10016     Calvin Ramsay      177      68          Right 2003-07-31   20
# 10017     Tomás Salazar      170      60          Right 2000-06-06   23
# 10018     Arda Kızıldağ      187      77          Right 1998-10-15   25
# 10019     Cristian Cauz      188      78           Left 1996-08-15   27
#
#          Nation Preferred Positions  OVR  POT        Value  GK Kicking  \
# 0        Norway                  ST   91   94  157000000.0          13
# 1        France              ST, LW   91   94  153500000.0           7
# 2       Belgium             CM, CAM   91   91  103000000.0           5
# 3       England                  ST   90   90  119500000.0          11
# 4       Belgium                  GK   90   90   63000000.0          76
# ...         ...                 ...  ...  ...          ...         ...
# 10015   Germany                  GK   65   75     625000.0          63
# 10016  Scotland             RWB, RB   65   81     700000.0           9
# 10017  Colombia                  CM   65   74     825000.0           8
# 10018    Turkey                  CB   65   72     725000.0          14
# 10019     Italy              LB, CB   65   66     700000.0          14
#
#        GK Reflexes  Ball Skills  Defence  Mental  Passing  Physical  Shooting  \
# 0                7         80.5     38.0    80.2     59.0      83.7      84.0
# 1                6         92.5     33.0    76.7     78.3      89.0      82.2
# 2               13         89.0     61.5    84.0     94.3      75.7      83.1
# 3               11         84.5     42.0    81.3     85.0      75.9      86.5
# 4               93         18.0     17.0    41.5     27.3      54.0      22.4
# ...            ...          ...      ...     ...      ...       ...       ...
# 10015           70         16.5     12.5    30.0     31.3      40.4      14.9
# 10016            8         66.0     58.0    58.7     60.7      70.7      47.0
# 10017           10         65.0     58.5    60.3     59.0      58.4      53.9
# 10018            9         48.0     67.5    55.2     52.0      63.1      40.8
# 10019            7         60.5     68.0    55.3     54.0      65.1      50.1
#
#        Goalkeeper
# 0            10.4
# 1             8.4
# 2            11.2
# 3            10.8
# 4            86.6
# ...           ...
# 10015        64.4
# 10016         9.4
# 10017         8.0
# 10018        11.8
# 10019         9.8
#
# [10020 rows x 20 columns]

# %% [markdown]
# <h3>What does each line mean? Does it matter if the lines have different meanings?</h3>

# %% [markdown]
# Each line in the provided data represents information about a specific player in a football (soccer) context.
#
# These lines provide a comprehensive overview of each player's characteristics and abilities. The differences in meanings among the lines are expected and reflect the diversity of player positions, attributes, and roles within a football team. The dataset captures a range of player types, from strikers (ST) and midfielders (CM, CAM) to goalkeepers (GK), each with their own set of skills and attributes.
#
# Analyzing this data allows for comparisons between players, understanding their strengths and weaknesses, and making informed decisions, such as scouting or selecting players for specific positions on a team.

# %% [markdown]
# <h3>Does the raw data have duplicate rows?</h3>

# %%
num_duplicated_rows = None
dupli=raw_df.duplicated()
count=0
for i in dupli:
    if i == True:
        count+=1
num_duplicated_rows=count

# %%
# TEST
if num_duplicated_rows == 0:
    print(f"Your raw data have no duplicated line.!")
else:
    if num_duplicated_rows > 1:
        ext = "lines"
    else:
        ext = "line"
    print(f"Your raw data have {num_duplicated_rows} duplicated " + ext + ". Please de-deduplicate your raw data.!")
# Out:
# Your raw data have no duplicated line.!

# %%
# De-deduplicate raw data
raw_df=raw_df.drop_duplicates()

# %% [markdown]
# <h3>What does each column mean?</h3>

# %% [markdown]
# <div>
#
# **Height**: The player's height.
#
# **Weight**: The player's weight.
#
# **Preferred Foot**: The foot that the player prefers to use (Left or Right).
#
# **Birth Date**: The player's date of birth.Age: The player's current age.
#
# **Preferred Positions**: The positions on the field that the player prefers to play.
#
# **OVR (Overall)**: The player's overall skill level or rating.
#
# **POT (Potential)**: The player's potential skill level or rating.
#
# **Value**: The estimated market value of the player.
#
# **Wage**: The player's weekly wage.
#
# **Ball Skills**: Composite score representing ball control and dribbling skills.
#
# **Defence**: Composite score representing defensive skills, combining slide tackle and stand tackle.
#
# **Mental**: The average of attributes related to mental skills (Aggression to Composure).
#
# **Passing**: The average of attributes related to passing skills (Crossing to Long Pass).
#
# **Physical**: The average of attributes related to physical skills (Acceleration to Jumping).
#
# **Shooting**: The average of attributes related to shooting skills (Heading to Volleys).
#
# **Goalkeeper**: The average of attributes related to goalkeeping skills.
# </div>

# %% [markdown]
# <h3>Save your processed data</h3>

# %%
raw_df.to_csv("data_footballer_processed.csv", index=False)
