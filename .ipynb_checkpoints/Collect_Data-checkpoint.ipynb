# %% [markdown]
# <div style="text-align: center; background-color: #5A96E3; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Collecting Data</div>

# %% [markdown]
# ## Group 17:
#
# | MSSV     | Họ tên         | Github                                        |Email                         |
# |----------|----------------|-----------------------------------------------|------------------------------|
# | 21120407 | Trần Phan Phúc Ân | [TranPhanPhucAn](https://github.com/TranPhanPhucAn) |21120407@student.hcmus.edu.vn |
# | 21120409 | Nguyễn Đức Duy Anh | [duyanh711](https://github.com/duyanh711) |21120409@student.hcmus.edu.vn |
# | 21120451 | Lê Bảo Hiếu | [baohieu1910](https://github.com/baohieu1910) |21120451@student.hcmus.edu.vn |    |
# | 21120539 | Trần Minh Quang | [21120539](https://github.com/21120539) |21120539@student.hcmus.edu.vn |    |

# %% [markdown]
# <h2>Import</h2>

# %%
#Necessary Packages
import time
import re
import requests
import numpy as np
import pandas as pd 
from bs4 import BeautifulSoup
import csv

# %% [markdown]
# <h2>Start crawling and save collected data</h2>

# %%
url="https://www.fifaindex.com/players"
HEADERS = {"User-Agent": "Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148"}
get_links=[]
for i in range(1,335):
    count=0
    r=requests.get(url+f"/?page={i}",headers=HEADERS)
    soup=BeautifulSoup(r.text,"html.parser")
    link_players=soup.find_all("a",attrs={"class":"link-player"})
    for link in link_players:
        if link:
            href_value = link.get("href")
        if count==0:  
            get_links.append(href_value)
            count=1
        else:
            count=0
with open("get_links.txt", "w") as file:
    for item in get_links:
        file.write("%s\n" % item)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       4 for i in range(1,335):
#       5     count=0
# ----> 6     r=requests.get(url+f"/?page={i}",headers=HEADERS)
#       7     soup=BeautifulSoup(r.text,"html.parser")
#       8     link_players=soup.find_all("a",attrs={"class":"link-player"})
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
HEADERS = {"User-Agent": "Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148"}
player_info = [ 
                "Preferred Foot ",
                "Birth Date ",
                "Age ",
                "Ball Control ",
                "Dribbling ",
                "Marking ",
                "Slide Tackle ",
                "Stand Tackle ",
                "Aggression ",
                "Reactions ",
                "Att. Position ",
                "Interceptions ",
                "Vision ",
                "Composure ",
                "Crossing ",
                "Short Pass ",
                "Long Pass ",
                "Acceleration ",
                "Stamina ",
                "Strength ",
                "Balance ",
                "Sprint Speed ",
                "Agility ",
                "Jumping ",
                "Heading ",
                "Shot Power ",
                "Finishing ",
                "Long Shots ",
                "Curve ",
                "FK Acc. ",
                "Penalties ",
                "Volleys ",
                "GK Positioning ",
                "GK Diving ",
                "GK Handling ",
                "GK Kicking ",
                "GK Reflexes "]
player_dict = { "Name ": [],
                "Height ":[],
                "Weight ":[],
                "Preferred Foot ":[],
                "Birth Date ":[],
                "Age ": [],
                "Nation": [],
                "Club" : [],
                "League" : [],
                "Preferred Positions ":[],
                "OVR " : [],
                "POT " : [],
                "Value " : [],
                "Wage ":[],
                "Ball Control ": [],
                "Dribbling ": [],
                "Marking ": [],
                "Slide Tackle ": [],
                "Stand Tackle ": [],
                "Aggression ": [],
                "Reactions ": [],
                "Att. Position ": [],
                "Interceptions ": [],
                "Vision ": [],
                "Composure ": [],
                "Crossing ": [],
                "Short Pass ": [],
                "Long Pass ": [],
                "Acceleration ": [],
                "Stamina ": [],
                "Strength ": [],
                "Balance ": [],
                "Sprint Speed ": [],
                "Agility ": [],
                "Jumping ": [],
                "Heading ": [],
                "Shot Power ": [],
                "Finishing ": [],
                "Long Shots ": [],
                "Curve ": [],
                "FK Acc. ": [],
                "Penalties ": [],
                "Volleys ": [],
                "GK Positioning ": [],
                "GK Diving ": [],
                "GK Handling ": [],
                "GK Kicking ": [],
                "GK Reflexes ": []
}
def collect_data(course_urls_file):
    #load paths from file
    url_file = open(course_urls_file)
    urls = url_file.readlines()
    urls_filtered = [item[:-1] for item in urls]
    
    Name = []
    Height = []
    Weight = []
    Nation = []
    Club = []
    League = []
    Preferred_Foot=[]
    Birth_Date=[]
    Age= []
    Preferred_Positions=[]
    OVR = []
    POT = []
    Value = []
    Wage=[]
    Ball_Skills= []
    Defence= []
    Mental= []
    Passing= []
    Physical= []
    Shooting= []
    Goalkeeper= [] 
    for url in urls_filtered:
        #TODO
        a = "https://www.fifaindex.com" + url
        r = requests.get(a,verify=True,headers=HEADERS)
        soup = BeautifulSoup(r.text,"html.parser")
        # Tìm thẻ h1
        h1_tag = soup.find("h1")
        
        # Xóa nội dung trong thẻ span
        if h1_tag.span:
            h1_tag.span.decompose()
        
        # Lấy nội dung trong thẻ h1 (không bao gồm thẻ span)
        name = h1_tag.text
        Name.append(name)
        height_weight = soup.find_all("span",attrs = {"class":"data-units-metric"})
        Height.append(height_weight[0].text)
        Weight.append(height_weight[1].text)
        nation = soup.find_all("a",attrs={"class":"link-nation"})
        Nation.append(nation[1].text)
        club = soup.find_all("a",attrs={"class":"link-team"})
        Club.append(club[1].text)
        league_link = club[0]['href']
        league = requests.get(f"https://www.fifaindex.com{league_link}",headers=HEADERS)        
        league_soup = BeautifulSoup(league.text,"html.parser")
        league_text = league_soup.find("a",attrs={"class":"link-league"})
        League.append(league_text.text)
        temp = soup.find_all("p", class_="")

        for i in temp:
            temp_text = i.contents[0]
            if temp_text=="Preferred Positions ":
                temp_position=i.find_all("span",attrs={"class":"position"})
                positions_list = [span.text.strip() for span in temp_position]
                positions = ", ".join(positions_list)
                # Preferred_Positions.append(positions)
                temp_list = player_dict[temp_text]
                temp_list.append(positions)
                player_dict[temp_text] = temp_list
            if temp_text in player_info:
                span_tag = i.find("span")
                span_content = span_tag.text.strip() if span_tag else None
                temp_list = player_dict[temp_text]
                temp_list.append(span_content)
                player_dict[temp_text] = temp_list
                
        check_text = soup.find_all("h5", class_="card-header")[0].text
        if check_text == "FIFA 22 Rankings ":
            h5_tag = soup.find_all("h5", class_="card-header")[1]
        else:
            h5_tag = soup.find_all("h5", class_="card-header")[0]
        # Tìm tất cả các thẻ span có class là "badge badge-dark rating"
        rating_spans = h5_tag.find_all("span", class_=re.compile(r"\b(?:badge|badge-dark|rating)\b"))
        ratings = [span.text for span in rating_spans]
        # Lấy giá trị từ các thẻ span
        OVR.append(ratings[0])
        POT.append(ratings[1])
        value_tag = soup.find("p", {"class" : "data-currency data-currency-euro"})
        if value_tag:
            content_inside_value = value_tag.contents[1]
            Value.append(content_inside_value.text.replace("€", ""))
            wage_tag = soup.find_all("p", {"class" : "data-currency data-currency-euro"})[1]
            content_inside_wage = wage_tag.contents[1]
            Wage.append(content_inside_wage.text.replace("€", ""))
        else:
            Value.append("None")
            Wage.append("None")
    player_dict["Name "] = Name
    player_dict["Height "] = Height
    player_dict["Weight "] = Weight
    player_dict["Nation"] = Nation
    player_dict["Club"] = Club
    player_dict["League"] = League
    player_dict["OVR "] = OVR
    player_dict["POT "] = POT
    player_dict["Value "] = Value
    player_dict["Wage "] = Wage
    data = pd.DataFrame(player_dict)
    data.rename(columns=lambda x: x.rstrip(), inplace=True)
    return data

# %%
data_footballer = collect_data("get_links.txt")
display(data_footballer)
# Out:
# ['England Premier League (1)']
#
#
#
#
# ['England Premier League (1)', 'France Ligue 1 (1)']
#
#
#
#
# ['England Premier League (1)', 'France Ligue 1 (1)', 'England Premier League (1)']
#
#
#
#
# ['England Premier League (1)', 'France Ligue 1 (1)', 'England Premier League (1)', 'Germany 1. Bundesliga (1)']
#
#
#
#
# ['England Premier League (1)', 'France Ligue 1 (1)', 'England Premier League (1)', 'Germany 1. Bundesliga (1)', 'Spain Primera Divisi처n (1)']
#
#
#
#
# ['England Premier League (1)', 'France Ligue 1 (1)', 'England Premier League (1)', 'Germany 1. Bundesliga (1)', 'Spain Primera Divisi처n (1)', 'Spain Primera Divisi처n (1)']
#
#
#
#
# ['England Premier League (1)', 'France Ligue 1 (1)', 'England Premier League (1)', 'Germany 1. Bundesliga (1)', 'Spain Primera Divisi처n (1)', 'Spain Primera Divisi처n (1)', 'Saudi Pro League (1)']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 data_footballer = collect_data("get_links.txt")
#       2 display(data_footballer)
#
# Cell In[33], line 139, in collect_data(course_urls_file)
#     137 Club.append(club[1].text)
#     138 league_link = club[0]['href']
# --> 139 league = requests.get(f"https://www.fifaindex.com{league_link}",headers=HEADERS)
#     140 league_soup = BeautifulSoup(league.text,"html.parser")
#     141 league_text = league_soup.find("a",attrs={"class":"link-league"})
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/site-packages/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/min3_ds-env/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
data_footballer.to_csv('data_footballer.csv',index=False)
